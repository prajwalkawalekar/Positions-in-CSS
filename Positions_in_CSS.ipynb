# %%
""" 1.  Write code to position 5 equal-sized (50 X 50px) boxes A, B, C, D, and E as follows
        a. box A 200px from the left, and 200px from the top of the viewport
        b. box B -30px left, and -30px above from the center of box A
        c. box B -30px right, and -30px above from the center of box A
        d. box B -30px left, and -30px below from the center of box A
        e. box B -30px right, and -30px below from the center of box A"""

        <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <style>
        .box {
            position: absolute;
            height: 50px;
            width: 50px;
            background-color: #ccc;
            border: 1px solid lightgreen;
            text-align: center;
        }

        .one {
        top: 200px;
        left: 200px;
        }

        .two {
          top: 170px;
          left: 170px;
        }

        .three {
        top: 170px;
        left: 230px;
        }

        .four {
        top: 230px;
        left: 170px;
        }

        .five {
        top: 230px;
        left: 230px;
        }
    </style>
</head>
<body>
    <div class="one box">A</div>
    <div class="two box">B</div>
    <div class="three box">c</div>
    <div class="four box">D</div>
    <div class="five box">E</div>
</body>
</html>

# %%
""" 2. Explain the difference between Absolute and Relative positioning.

Absolute Positioning
- Removes the element from the normal document flow.
- Positions the element relative to its nearest positioned ancestor (or the body if none).
- Uses top, right, bottom, and left properties to specify the exact position.

Relative Positioning
- Keeps the element in the normal document flow.
- Positions the element relative to its original position.
- Uses top, right, bottom, and left properties to specify the offset from its original position. """

# %%
3.  """ Create a card as shown in the picture below. (You can use CSS float property only for layout). """

<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <style>
        .card {
            border: 1px solid #ccc;
            width: 850px; /* Adjust as needed */
            font-family: sans-serif;
            background-color:blanchedalmond;
            overflow: hidden; /* Clear floats */
            padding: 20px;
            box-sizing: border-box; /* Include padding in width */
        }

        .card-text {
            float: left;
            width: 60%; /* Adjust width as needed */
            padding-right: 20px;
            box-sizing: border-box;
        }

        .card-image {
            float: right;
            width: 40%; /* Adjust width as needed */
        }

        .card-image img {
            width: 100%;
            height: auto;
            display: block;
        }

        h2 {
            color: #333;
            margin-top: 0;
        }

        p {
            color: #555;
            line-height: 1.6;
            margin-bottom: 10px;
        }
    </style>
</head>
<body>
    <div class="card">
        <div class="card-text">
            <h2>The Earth!!!</h2>
            <p>Nature is Earth's masterpiece, a symphony of life composed through millennia. Its landscapes whisper tales of ancient mountains, winding rivers, and flourishing forests, reminding us of the planet's boundless beauty. From delicate petals to towering redwoods, nature's artistry stirs awe and reconnects us to the essence of existence. Nature is Earth's masterpiece, a symphony of life composed through millennia. Its landscapes whisper tales of ancient mountains, winding rivers, and flourishing forests.</p>
        </div>
        <div class="card-image">
            <img src="https://tse1.mm.bing.net/th?id=OIP.Tr5A15H00S-ZL87lTzOMcgHaGM&pid=Api&P=0&h=180" alt="Abstract Earth Image">
        </div>
    </div>
</body>
</html>

# %%
""" 4. Create a simple header that sticks to the top of a webpage upon scrolling."""

<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <title>Navbar Without Flex/Grid</title>
    <style>
        body {
    margin: 0;
    font-family: Arial, sans-serif;
    background-color: #fff;
    color: #222;
}

.navbar {
    background-color: #1e1e1e;
    padding: 10px 20px;
    height: 50px;
    line-height: 50px;
    overflow: hidden;
    border-bottom: 1px solid #444;
    position: sticky;
    top: 0px;
}

.logo {
    display: inline-block;
    color: white;
    font-weight: bold;
    font-size: 16px;
}

.nav-links {
    display: inline-block;
    list-style-type: none;
    margin: 0;
    padding: 0;
    margin-left: 1300px;
}

.nav-links li {
    display: inline;
    margin-right: 20px;
}

.nav-links a {
    color: #aaa;
    text-decoration: none;
    font-weight: normal;
}

.nav-links a.active {
    color: white;
    font-weight: bold;
}

.cta-button {
    float: right;
}

.cta-button a {
    /* background-color: #ffd700; */
    border: 1px solid #ffd700;
    padding: 8px 15px;
    color: #ffd700;
    border-radius: 7px;
    text-decoration: none;
    font-weight: bold;
}

.content {
    padding: 20px;
}

    </style>
quod eveniet sapiente delectus voluptatum repudiandae neque autem distinctio amet vero? Blanditiis iusto accusantium sunt explicabo nobis. Commodi quia magni consectetur. Esse eos nesciunt eligendi corporis tempora, sunt officiis quas voluptatem pariatur minima itaque quam distinctio iusto dolores cupiditate repellat quis sed recusandae? Ad laboriosam, illo amet, alias sapiente soluta fugiat maxime iure repudiandae recusandae quibusdam perferendis ab eius, minus voluptatum qui mollitia laudantium nam? Inventore culpa at, facere aspernatur officia laboriosam laudantium, error, consectetur perferendis hic mollitia eveniet nemo ipsum fuga asperiores minima iste voluptates incidunt? Ipsa, nulla blanditiis alias deserunt suscipit laborum, nostrum corporis ex, a libero quo error et inventore excepturi! Neque, delectus? Accusantium ratione commodi, minus expedita nihil impedit nulla voluptatum natus nam atque incidunt eum ab in minima vero laborum eius nostrum itaque animi repellat dignissimos provident libero amet! Vel! Lorem ipsum dolor sit amet consectetur adipisicing elit. Aperiam ullam quis a! Facilis sunt cum rerum quos doloribus odio sed inventore fuga sint cumque quod vel, animi voluptatibus consequuntur sequi quia. Dolorum, voluptatibus quibusdam eum, a ratione cupiditate aut tenetur, odit aspernatur tempore animi tempora rerum nisi? Laborum asperiores aperiam, autem similique explicabo aut quibusdam nihil soluta commodi distinctio excepturi omnis nisi natus. Molestiae, inventore excepturi ipsum commodi natus animi tempore placeat consequatur qui, velit laboriosam vel esse autem possimus sequi accusamus veritatis, dolore alias sunt rem delectus dolores cum eligendi dolorem? Exercitationem vero architecto quia minus officiis ab eaque accusamus aut quibusdam doloribus reiciendis recusandae nostrum quos at, minima repellat repellendus est voluptate, inventore possimus tempora dolorem asperiores consectetur. Expedita dolorum quasi, fuga aliquid laboriosam vel alias earum iusto necessitatibus. Corporis aut expedita similique ullam quaerat magnam facilis id distinctio, maxime natus! Deserunt non iusto nam neque ratione accusamus consequuntur soluta dicta alias reprehenderit et itaque placeat, assumenda sapiente aspernatur inventore maiores, veritatis repellat similique ex, ducimus ab error eaque. Non ullam nesciunt eligendi laborum neque nostrum hic iusto minus. Reiciendis magnam libero doloremque, facere, repellat itaque dolorum beatae veniam id sit officiis voluptate autem nisi eaque, corrupti eligendi.</p>
    </div>
</body>
</html>

# %%
""" 5. Explain the z-index, with a code example."""

""" Z-index is a CSS property that controls the stacking order of elements that overlap. It specifies which element appears on top of others.

Key Points:
1. Higher value: Element appears on top.
2. Lower value: Element appears below.
3. Default value: 0 (auto).
4. Positioning required: Z-index only works on positioned elements (e.g., position: absolute, relative, fixed, or sticky). """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Z-Index</title>
    <style>
        div{
            border: 1px solid black;
            height: 150px;
            width: 60%;
            margin: 5px;
        }
        .one{
            background-color: antiquewhite;
            z-index: 1;
            left: 100px;
        }
        .two{
            background-color: aqua;
            z-index: 2;
            top: -50px;
            left: 80px;
            position: relative;
        }
        .three{
            background-color: blueviolet;
            z-index: 3;
            top: -70px;
            left: 150px;
            position: relative;
        }
        .four{
            background-color: bisque;
            z-index: 4;
            top: -90px;
            left: 200px;
            position: relative;
        }
    </style>
</head>
<body>
    <div class="one"></div>
    <div class="two"></div>
    <div class="three"></div>
    <div class="four"></div>
</body>
</html>
